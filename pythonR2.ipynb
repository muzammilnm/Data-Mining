# %%
from scipy import stats
import  pandas as pd
pd.read_csv("DataP2.csv")
#df.read_csv("Data.csv")
# Out:
#     matematika  fisika  kimia  biologi
# 0           71      59     33       16
# 1           83      29     84       79
# 2           30      38     90       22
# 3           74      60     66       16
# 4           46      68     62       22
# 5           80      19     99       62
# 6           17      58     35       16
# 7           91       9     80        8
# 8           24      25     89       61
# 9           96      41     68       75
# 10          27      13     51       44
# 11          49      69     79       16
# 12          63      12     65       86
# 13          49      94     26        1
# 14          29      87     78      100
# 15          85      64     64       87
# 16          48       0     35        6
# 17          51      85     69       92
# 18          97      35     26       29
# 19          63      47     88        7

# %%
df=pd.read_csv("DataP2.csv")
print(df['matematika'].describe())
print("jumlah data",df['matematika'].count())
print('====');
print(df['fisika'].describe())
print("jumlah data",df['fisika'].count())
print('====');
print(df['kimia'].describe())
print("jumlah data",df['kimia'].count())
print('====');
print(df['biologi'].describe())
print("jumlah data",df['biologi'].count())
# Out:
# count    20.000000
# mean     58.650000
# std      25.377725
# min      17.000000
# 25%      42.000000
# 50%      57.000000
# 75%      80.750000
# max      97.000000
# Name: matematika, dtype: float64
# jumlah data 20
# ====
# count    20.000000
# mean     45.600000
# std      27.861311
# min       0.000000
# 25%      23.500000
# 50%      44.000000
# 75%      65.000000
# max      94.000000
# Name: fisika, dtype: float64
# jumlah data 20
# ====
# count    20.000000
# mean     64.350000
# std      22.857165
# min      26.000000
# 25%      47.000000
# 50%      67.000000
# 75%      81.000000
# max      99.000000
# Name: kimia, dtype: float64
# jumlah data 20
# ====
# count     20.000000
# mean      42.250000
# std       34.087928
# min        1.000000
# 25%       16.000000
# 50%       25.500000
# 75%       76.000000
# max      100.000000
# Name: biologi, dtype: float64
# jumlah data 20

# %%
from scipy import stats
mode = stats.mode(df)
print(mode)
# Out:
# ModeResult(mode=array([[49,  0, 26, 16]], dtype=int64), count=array([[2, 1, 2, 4]]))

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
df=pd.read_csv("DataP2.csv",usecols=[0])
#print(df)
sns.distplot(df);

# %%
df1=pd.read_csv("DataP2.csv",usecols=[1])
#print(df)
sns.distplot(df1);

# %%
df2=pd.read_csv("DataP2.csv",usecols=[2])
#print(df)
sns.distplot(df2);

# %%
df3=pd.read_csv("DataP2.csv",usecols=[3])
#print(df)
sns.distplot(df3);

# %%
for i in range(4):
    df=pd.read_csv("DataP2.csv",usecols=[i])
    #print(df)
    sns.distplot(df);
